# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielBravoPatino/AD2003B/blob/main/labPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PRACTICA
# ### AD2004B.403.M2.EF2023
# ### Laboratorio de PANDAS
#
#
#
# > En este Lab practicaras el uso de **Pandas** para realizar análisis de datos. Partiremos de la carga de datos desde un archivo de Excel para despues manipular visualizar esto datos con Python.
# EL archivo de Excel debe de estar en Github.
#
#
#
# ##### Nombre del archivo: "labPandas"
# #### Utilizaremos el archivo "Superstore.xls"

# %% [markdown]
# ## PANDAS
# https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html
#
#
# **Importar** un archivo de datos con **pandas**
# >Como primer paso se debe importar la libreria de Pandas, lo cual nos da acceso a las funciones necesarias para manipulación de los datos.

# %%
# Importamos la Libreria pandas con el alias "pd"
import pandas as pd

# %% [markdown]
# ## Importar archivo de Excel
# > Es importante que tengan correcta la ruta donde esta el archivo, en este caso el archivo debe estar en el repositorio correspondiente a la clase de GitHub.

# %%
#Importar archivo en un dataframe
URL= '/content/Superstore.xls'
datos = pd.read_excel(URL)
datos

# %% [markdown]
# # Conoce los Datos.
# Identificar y documentar de manera general que contiene el archivo de datos.
# Una buena idea es crear un glosario de términos donde se describa cada uno de los datos manejados.

# %%
#Ejecuta las intrucciones necesarias para conocer los datos. 
# METADATOS
print(dfDatos.columns) #nombre de las columnas
# Out:
# Index(['Order ID', 'Customer ID', 'Customer Name', 'Segment', 'City',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
datos.dtypes #tipo de datos
# Out:
# Order ID          object
# Customer ID       object
# Customer Name     object
# Segment           object
# City              object
# Postal Code      float64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
datos.shape #tamaño del dataframe
# Out:
# (9994, 15)

# %%
# DATOS: Observa los datos de manera inicial, oberva los primeros n y los ultimos n, donde pruebes con varios valores de n
datos.head(10) #lo sprimeros 10 renlones de datos
# Out:
#          Order ID Customer ID        Customer Name      Segment  \
# 0  CA-2018-140326    HW-14935      Helen Wasserman    Corporate
# 1  CA-2016-130785    AG-10900        Arthur Gainer     Consumer
# 2  CA-2015-105249    DH-13675        Duane Huffman  Home Office
# 3  CA-2018-125472    BD-11725     Bruce Degenhardt     Consumer
# 4  CA-2016-118423    DP-13390        Dennis Pardue  Home Office
# 5  CA-2015-156349    ML-17395  Marina Lichtenstein    Corporate
# 6  CA-2017-165848    EN-13780        Edward Nazzal     Consumer
# 7  US-2015-123183    GR-14560    Georgia Rosenberg    Corporate
# 8  CA-2015-133592    KM-16375     Katherine Murray  Home Office
# 9  CA-2018-161200    SV-20365          Seth Vernon     Consumer
#
#             City  Postal Code   Region       Product ID   Category  \
# 0        Chicago      60653.0  Central  FUR-BO-10000112  Furniture
# 1      San Diego      92105.0     West  FUR-BO-10000330  Furniture
# 2  San Francisco      94122.0     West  FUR-BO-10000330  Furniture
# 3      Lafayette      70506.0    South  FUR-BO-10000330  Furniture
# 4         Peoria      61604.0  Central  FUR-BO-10000362  Furniture
# 5    Los Angeles      90008.0     West  FUR-BO-10000362  Furniture
# 6  New York City      10035.0     East  FUR-BO-10000362  Furniture
# 7     Wilmington      19805.0     East  FUR-BO-10000362  Furniture
# 8     Providence       2908.0     East  FUR-BO-10000362  Furniture
# 9      Lafayette      70506.0    South  FUR-BO-10000468  Furniture
#
#   Sub-Category                                       Product Name     Sales  \
# 0    Bookcases   Bush Birmingham Collection Bookcase, Dark Cherry   825.174
# 1    Bookcases  Sauder Camden County Barrister Bookcase, Plank...   411.332
# 2    Bookcases  Sauder Camden County Barrister Bookcase, Plank...   411.332
# 3    Bookcases  Sauder Camden County Barrister Bookcase, Plank...   241.960
# 4    Bookcases                 Sauder Inglewood Library Bookcases   359.058
# 5    Bookcases                 Sauder Inglewood Library Bookcases   290.666
# 6    Bookcases                 Sauder Inglewood Library Bookcases   136.784
# 7    Bookcases                 Sauder Inglewood Library Bookcases  1025.880
# 8    Bookcases                 Sauder Inglewood Library Bookcases   341.960
# 9    Bookcases            O'Sullivan 2-Shelf Heavy-Duty Bookcases   145.740
#
#    Quantity  Discount    Profit
# 0         9      0.30 -117.8820
# 1         4      0.15   -4.8392
# 2         4      0.15   -4.8392
# 3         2      0.00   33.8744
# 4         3      0.30  -35.9058
# 5         2      0.15   27.3568
# 6         1      0.20    5.1294
# 7         6      0.00  235.9524
# 8         2      0.00   78.6508
# 9         3      0.00   23.3184

# %%
datos.tail(10) #los últimos 10 renglones de datos
# Out:
#             Order ID Customer ID       Customer Name      Segment  \
# 9984  CA-2015-165309    KD-16270       Karen Daniels     Consumer
# 9985  CA-2017-117590    GH-14485           Gene Hale    Corporate
# 9986  CA-2018-145233    DV-13465    Dianna Vittorini     Consumer
# 9987  CA-2015-136399    CC-12100     Chad Cunningham  Home Office
# 9988  CA-2018-122196    CA-12265  Christina Anderson     Consumer
# 9989  CA-2018-144498    MB-18085          Mick Brown     Consumer
# 9990  CA-2015-167199    ME-17320       Maria Etezadi  Home Office
# 9991  CA-2018-121048    TC-21295       Toby Carlisle     Consumer
# 9992  CA-2018-167395    KM-16720        Kunst Miller     Consumer
# 9993  CA-2016-128608    CS-12490    Cindy Schnelling    Corporate
#
#              City  Postal Code   Region       Product ID    Category  \
# 9984      Houston      77095.0  Central  TEC-PH-10004959  Technology
# 9985   Richardson      75080.0  Central  TEC-PH-10004977  Technology
# 9986       Denver      80219.0     West  TEC-PH-10004977  Technology
# 9987  Los Angeles      90049.0     West  TEC-PH-10004977  Technology
# 9988   Wilmington      19805.0     East  TEC-PH-10004977  Technology
# 9989    Charlotte      28205.0    South  TEC-PH-10004977  Technology
# 9990    Henderson      42420.0    South  TEC-PH-10004977  Technology
# 9991  Westminster      92683.0     West  TEC-PH-10004977  Technology
# 9992       Lowell       1852.0     East  TEC-PH-10004977  Technology
# 9993       Toledo      43615.0     East  TEC-PH-10004977  Technology
#
#      Sub-Category                            Product Name     Sales  Quantity  \
# 9984       Phones  Classic Ivory Antique Telephone ZL1810   241.176         3
# 9985       Phones                             GE 30524EE4  1097.544         7
# 9986       Phones                             GE 30524EE4   470.376         3
# 9987       Phones                             GE 30524EE4   627.168         4
# 9988       Phones                             GE 30524EE4   391.980         2
# 9989       Phones                             GE 30524EE4   627.168         4
# 9990       Phones                             GE 30524EE4   391.980         2
# 9991       Phones                             GE 30524EE4   470.376         3
# 9992       Phones                             GE 30524EE4   979.950         5
# 9993       Phones                             GE 30524EE4   235.188         2
#
#       Discount    Profit
# 9984       0.2   15.0735
# 9985       0.2  123.4737
# 9986       0.2   52.9173
# 9987       0.2   70.5564
# 9988       0.0  113.6742
# 9989       0.2   70.5564
# 9990       0.0  113.6742
# 9991       0.2   52.9173
# 9992       0.0  284.1855
# 9993       0.4  -43.1178

# %% [markdown]
# # **FILTROS**

# %% [markdown]
# ### Mostrar columas especificas de un dataframe.
# Crea un dataframe "dfCLientes" donde almacenes el ID del CLiente y su nombre.
# Muestra el dataframe.
#
# dataframe[["col1", "col2"]]

# %%
dfClientes= datos[['Customer ID', 'Customer Name']]
dfClientes
# Out:
#      Customer ID     Customer Name
# 0       HW-14935   Helen Wasserman
# 1       AG-10900     Arthur Gainer
# 2       DH-13675     Duane Huffman
# 3       BD-11725  Bruce Degenhardt
# 4       DP-13390     Dennis Pardue
# ...          ...               ...
# 9989    MB-18085        Mick Brown
# 9990    ME-17320     Maria Etezadi
# 9991    TC-21295     Toby Carlisle
# 9992    KM-16720      Kunst Miller
# 9993    CS-12490  Cindy Schnelling
#
# [9994 rows x 2 columns]

# %% [markdown]
# **CLIENTES**.
# ¿Cuantos clientes se tienen?
# Crea un dataframe con los IDs y nombre de clientes sin que estos se repitan.
# Muestra la información.

# %%
dfClientes.drop_duplicates('Customer ID')
# Out:
#      Customer ID     Customer Name
# 0       HW-14935   Helen Wasserman
# 1       AG-10900     Arthur Gainer
# 2       DH-13675     Duane Huffman
# 3       BD-11725  Bruce Degenhardt
# 4       DP-13390     Dennis Pardue
# ...          ...               ...
# 4558    MW-18235  Mitch Willingham
# 5061    PB-19210    Phillip Breyer
# 6029    BD-11560    Brendan Dodson
# 6744    CH-12070       Cathy Hwang
# 9921    JR-15700    Jocasta Rupert
#
# [793 rows x 2 columns]

# %% [markdown]
# **Analiza los datos unicos.**
#
# Obten la lista de ciudades,segmentos, regiones y categorias. De cada uno conoce la cantidad y visualiza las listas.
# Crea un dataframe nuevo por cada consulta, el unique genera un arreglo numpy, conviertelo a dataframe, vizualizalo.

# %%
ciudad= datos[['City']]
segmento= datos[['Segment']]
region = datos[['Region']]
categoria= datos[['Category']]

# %% [markdown]
# # **Filtros con**  iloc - loc
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html?highlight=iloc#pandas.DataFrame.iloc
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html

# %% [markdown]
# Con la instrucción iloc y el dataframe dfDatos
#
# *   Muestra los primeros 10 registros.
# *   Muestra los registros del 20 al 25.
# *   Muestra 10 registros con indices seleccionados aleatoreamente
# *   Muestra los registros del 100 al 120, pero solo las columnas 4, 5 y 6

# %%
# iloc
print(datos.iloc[1:11])
print(datos.iloc[20:26])
print(datos.iloc[100:121, 4:6])

# %% [markdown]
# Con la instrucción loc:
#
#
# *   En una nuev df Asigna el ID de la orden como dato indice.
# *   Realiza la busqueda de la orden "CA-2015-154599"
# *   Obtnen los registros con Sales mayor a 5000. ¿cuantos son?

# %%
# loc
dfOrden = datos[['Order ID']]

# %%
datos.loc[datos['Order ID']=='CA-2015-154599',:]
# Out:
#             Order ID Customer ID Customer Name    Segment           City  \
# 24    CA-2015-154599    KN-16450   Kean Nguyen  Corporate  Redondo Beach
# 4200  CA-2015-154599    KN-16450   Kean Nguyen  Corporate  Redondo Beach
# 9205  CA-2015-154599    KN-16450   Kean Nguyen  Corporate  Redondo Beach
# 9362  CA-2015-154599    KN-16450   Kean Nguyen  Corporate  Redondo Beach
#
#       Postal Code Region       Product ID         Category Sub-Category  \
# 24        90278.0   West  FUR-BO-10001337        Furniture    Bookcases
# 4200      90278.0   West  OFF-BI-10002764  Office Supplies      Binders
# 9205      90278.0   West  TEC-PH-10000576       Technology       Phones
# 9362      90278.0   West  TEC-PH-10001557       Technology       Phones
#
#                                            Product Name     Sales  Quantity  \
# 24       O'Sullivan Living Dimensions 2-Shelf Bookcases   308.499         3
# 4200  Recycled Pressboard Report Cover with Reinforc...    18.088         7
# 9205                             AT&T 1080 Corded phone   438.368         4
# 9362                                      Pyle PMP37LED  1075.088        14
#
#       Discount   Profit
# 24        0.15 -18.1470
# 4200      0.20   6.5569
# 9205      0.20  38.3572
# 9362      0.20  94.0702

# %%
datos[datos['Sales']>5000]
# Out:
#             Order ID Customer ID         Customer Name      Segment  \
# 3547  CA-2017-117121    AB-10105         Adrian Barton     Consumer
# 3731  CA-2015-116904    SC-20095          Sanjit Chand     Consumer
# 4418  CA-2016-145352    CM-12385  Christopher Martinez     Consumer
# 4426  CA-2018-135909    JW-15220             Jane Waco    Corporate
# 4903  CA-2018-138289    AR-10540           Andy Reiter     Consumer
# 7957  CA-2015-143917    KL-16645          Ken Lonsdale     Consumer
# 8939  US-2017-140158    DR-12940         Daniel Raglin  Home Office
# 8985  CA-2018-127180    TA-21385          Tom Ashbrook  Home Office
# 8986  CA-2018-166709    HL-15040          Hunter Lopez     Consumer
# 8987  CA-2017-143714    CC-12370    Christopher Conant     Consumer
# 8988  CA-2017-118689    TC-20980          Tamara Chand    Corporate
# 8989  CA-2018-140151    RB-19360          Raymond Buch     Consumer
# 9010  CA-2015-139892    BM-11140          Becky Martin     Consumer
# 9022  US-2017-107440    BS-11365          Bill Shonely    Corporate
# 9023  CA-2018-143112    TS-21370          Todd Sumrall    Corporate
# 9025  CA-2015-145541    TB-21400      Tom Boeckenhauer     Consumer
# 9026  CA-2017-158841    SE-20110          Sanjit Engle     Consumer
# 9050  CA-2015-145317    SM-20320           Sean Miller  Home Office
# 9091  US-2018-168116    GT-14635        Grant Thornton    Corporate
#
#                City  Postal Code   Region       Product ID         Category  \
# 3547        Detroit      48205.0  Central  OFF-BI-10000545  Office Supplies
# 3731    Minneapolis      55407.0  Central  OFF-BI-10001120  Office Supplies
# 4418        Atlanta      30318.0    South  OFF-BI-10003527  Office Supplies
# 4426     Sacramento      95823.0     West  OFF-BI-10003527  Office Supplies
# 4903        Jackson      49201.0  Central  OFF-BI-10004995  Office Supplies
# 7957  San Francisco      94122.0     West  OFF-SU-10000151  Office Supplies
# 8939     Providence       2908.0     East  TEC-CO-10001449       Technology
# 8985  New York City      10024.0     East  TEC-CO-10004722       Technology
# 8986         Newark      19711.0     East  TEC-CO-10004722       Technology
# 8987   Philadelphia      19120.0     East  TEC-CO-10004722       Technology
# 8988      Lafayette      47905.0  Central  TEC-CO-10004722       Technology
# 8989        Seattle      98115.0     West  TEC-CO-10004722       Technology
# 9010    San Antonio      78207.0  Central  TEC-MA-10000822       Technology
# 9022       Lakewood       8701.0     East  TEC-MA-10001047       Technology
# 9023  New York City      10035.0     East  TEC-MA-10001047       Technology
# 9025  New York City      10024.0     East  TEC-MA-10001127       Technology
# 9026      Arlington      22204.0    South  TEC-MA-10001127       Technology
# 9050   Jacksonville      32216.0    South  TEC-MA-10002412       Technology
# 9091     Burlington      27217.0    South  TEC-MA-10004125       Technology
#
#      Sub-Category                                       Product Name  \
# 3547      Binders   GBC Ibimaster 500 Manual ProClick Binding System
# 3731      Binders               Ibico EPK-21 Electric Binding System
# 4418      Binders  Fellowes PB500 Electric Punch Plastic Comb Bin...
# 4426      Binders  Fellowes PB500 Electric Punch Plastic Comb Bin...
# 4903      Binders          GBC DocuBind P400 Electric Binding System
# 7957     Supplies        High Speed Automatic Electric Letter Opener
# 8939      Copiers               Hewlett Packard LaserJet 3310 Copier
# 8985      Copiers              Canon imageCLASS 2200 Advanced Copier
# 8986      Copiers              Canon imageCLASS 2200 Advanced Copier
# 8987      Copiers              Canon imageCLASS 2200 Advanced Copier
# 8988      Copiers              Canon imageCLASS 2200 Advanced Copier
# 8989      Copiers              Canon imageCLASS 2200 Advanced Copier
# 9010     Machines          Lexmark MX611dhe Monochrome Laser Printer
# 9022     Machines   3D Systems Cube Printer, 2nd Generation, Magenta
# 9023     Machines   3D Systems Cube Printer, 2nd Generation, Magenta
# 9025     Machines  HP Designjet T520 Inkjet Large Format Printer ...
# 9026     Machines  HP Designjet T520 Inkjet Large Format Printer ...
# 9050     Machines  Cisco TelePresence System EX90 Videoconferenci...
# 9091     Machines          Cubify CubeX 3D Printer Triple Head Print
#
#           Sales  Quantity  Discount     Profit
# 3547   9892.740        13       0.0  4946.3700
# 3731   9449.950         5       0.0  4630.4755
# 4418   6354.950         5       0.0  3177.4750
# 4426   5083.960         5       0.2  1906.4850
# 4903   5443.960         4       0.0  2504.2216
# 7957   8187.650         5       0.0   327.5060
# 8939   5399.910         9       0.0  2591.9568
# 8985  11199.968         4       0.2  3919.9888
# 8986  10499.970         3       0.0  5039.9856
# 8987   8399.976         4       0.4  1119.9968
# 8988  17499.950         5       0.0  8399.9760
# 8989  13999.960         4       0.0  6719.9808
# 9010   8159.952         8       0.4 -1359.9920
# 9022   9099.930         7       0.0  2365.9818
# 9023   5199.960         4       0.0  1351.9896
# 9025   6999.960         4       0.0  2239.9872
# 9026   8749.950         5       0.0  2799.9840
# 9050  22638.480         6       0.5 -1811.0784
# 9091   7999.980         4       0.5 -3839.9904

# %% [markdown]
# ## Estadisticas básicas con pandas
# https://datatofish.com/use-pandas-to-calculate-stats-from-an-imported-csv-file/
#
# df.describe()
# Mean, sum, Maximum, Minimum, Count, Median, Standard deviation, Variance.
#
# Obrten las estadisticas de los datos.
#
#
# _________

# %%
# Estadisticas basicas
print(max(datos))
print(min(datos))
# Out:
# Sub-Category
# Category

# %% [markdown]
# **### Estadisticas con una condición**

# %% [markdown]
# Obten el promedio de utilidad de la región Central
#
# Ejemplo de salida:
#
# ***Promedio de utilidad de ordenes de la región central : 23.45***

# %%
# utiliza la intrucción loc para filtrar
#Conteo de frecuencias por observaciones únicas
print(datos['Region'].value_counts())
sum(datos.loc[datos['Region']=='Central',:])
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-af81b504cbde> in <module>
#       2 #Conteo de frecuencias por observaciones únicas
#       3 print(datos['Region'].value_counts())
# ----> 4 sum(datos.loc[datos['Region']=='Central',:])
#       5
#       6
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# Obten la suma de ventas de la categoría "Technology"

# %% [markdown]
# # **Group By**
# >La instrucción **groupby** realiza agrupamientos por uno o más datos, de tal forma que podremos realizar cálculos de datos por esos mismos grupos.

# %% [markdown]
# **TOP TEN x Ventas**
#
# Obten las ventas (cantidad , ventas , descuento) por ciudad ordenado de manera descendente en cuanto a las ventas.

# %%
#Primer paso usar groupby y generar un df
#Ordenar el daraframe de manera descendente y mostrar los primeros 10

# %% [markdown]
# **Generar otras dos vistas que sean de utilidad (con el groupby)**
# Analizar otras dos vistas que consideran puden ser utiles para conocer más sobre los datos.

# %% [markdown]
# # **EXPORTACIÓN**
#
# Exportar los df a archivos de EXCEL.

# %%
# Exportar un df a un archivo de EXCEL.

# %% [markdown]
# ---
#
#
# # **SEGUNDA PARTE**

# %% [markdown]
# ## ¿y las Gráficas?
#
# Veamos la libreria **matplotlib**

# %%
import matplotlib.pyplot as plt  # solo importamos del módulo  pyplot

# %% [markdown]
# ### NORMALIZAR
# Para poder comparar las ventas con los descuentos y ver si tienen una correlación debemos de ponerlos en una misma escala, para esto utilizremos la libreria **sklearn**

# %%
from sklearn import preprocessing
import seaborn as sns
